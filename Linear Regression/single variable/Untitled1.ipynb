# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df =pd.read_csv("homeprices.csv")
df
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('Area in sqft')
plt.ylabel('Price in USD')
plt.scatter(df.Area,df.Price,color='red',marker='+')
plt.plot(df.Area,reg.predict(df[['Area']]),color='blue')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['Area']],df.Price)
# Out:
# LinearRegression()

# %%
reg.predict(np.array([[3300]]))
# Out:
# C:\Users\SAKET\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
d=pd.read_csv("areas.csv")
d
# Out:
#    Area
# 0  3200
# 1  4855
# 2  3544
# 3  7025
# 4  4580
# 5  4625
# 6  5500
# 7  4780
# 8  8000

# %%
p=reg.predict(d)

# %%
d['Prices']=p

# %%
d
# Out:
#    Area        Prices
# 0  3200  6.151370e+05
# 1  4855  8.398656e+05
# 2  3544  6.618479e+05
# 3  7025  1.134525e+06
# 4  4580  8.025240e+05
# 5  4625  8.086344e+05
# 6  5500  9.274486e+05
# 7  4780  8.296815e+05
# 8  8000  1.266918e+06

# %%
d.to_csv("prediction.csv")

# %%
import joblib

# %%
model = linear_model.LinearRegression()
model.fit(df[['Area']],df.Price)
joblib.dump(model,'model_joblib')
# Out:
# ['model_joblib']

# %%
mj=joblib.load('model_joblib')

# %%
mj.predict(np.array([[3300]]))
# Out:
# C:\Users\SAKET\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])
